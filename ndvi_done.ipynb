# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open('/content/433514131_1521788628679533_5377477013670386171_n.jpg')

image = np.array(image)

red = image[:, :, 0].astype(float)
nir = image[:, :, 1].astype(float)

ndvi = (nir - red) / (nir + red)

plt.imshow(ndvi, cmap='RdYlGn')
plt.colorbar()
plt.title('NDVI ')
plt.show()
# Out:
# <ipython-input-2-a74afa01f593>:12: RuntimeWarning: invalid value encountered in divide
#   ndvi = (nir - red) / (nir + red)
